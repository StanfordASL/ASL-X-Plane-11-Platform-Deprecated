# %%
from PIL import Image  # Will need to make sure PIL is installed
import mss
import matplotlib.pyplot as plt
import cv2
import numpy as np
from aslxplane.simulation.corruptions import Rain

# %%
screenshotter = mss.mss()
monitor = screenshotter.monitors[1]
padding = 100
monitor["left"] += padding
monitor["top"] += padding
monitor["width"] -= padding
monitor["height"] -= padding
screenshot = screenshotter.grab(monitor)

# %%
monitor
# Out:
# {'left': 100, 'top': 100, 'width': 3740, 'height': 2060}

# %%
img = cv2.cvtColor(np.array(screenshot),
                       cv2.COLOR_BGRA2RGB)[230:, :, :]
img = cv2.resize(img, (360, 200))
# img = Image.fromarray(img)

# %%
plt.imshow(img)

# %%
rain = Rain()
img_rain = rain.add_corruption(img)

# %%
plt.imshow(img_rain)

# %%
img = Image.frombytes("RGB", screenshot.size, screenshot.bgra, "raw", "BGRX")  # Convert to PIL.Image

# %%
plt.imshow(img)

# %%
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /home/rohan/Projects/XPlane-ASL/notebooks/test_screengrabs.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/rohan/Projects/XPlane-ASL/notebooks/test_screengrabs.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> assert(rain.aug is None)
#
# AssertionError:

# %%
constraints_1 = [-1,1]
constraints_2 = [-2,2]
[np.array([c1,c2]) for c1, c2 in zip(constraints_1, constraints_2)]
# Out:
# [array([-1, -2]), array([1, 2])]
